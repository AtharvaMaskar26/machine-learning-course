# %% [markdown]
# ## Random Forest Regression
#
# It is a type of Ensemble Learning.
# Ensemble Learning is when you take multiple algorithms and put them together.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Importing the libraries

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# ### Importing the dataset

# %%
dataset = pd.read_csv('Position_Salaries.csv')

X = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# ### Training the Random Forest Regression Model on the whole dataset

# %%
from sklearn.ensemble import RandomForestRegressor

# We mention how many trees we want
regressor = RandomForestRegressor(n_estimators=10, random_state=0)

regressor.fit(X, y)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=0)

# %% [markdown]
# ### Predicting a new result

# %%
regressor.predict([[6.5]])
# Out:
# array([167000.])

# %% [markdown]
# ### Visualising the random forest Regression Results (Higher Resolution)

# %%
X_grid = np.arange(min(X), max(X), 0.1)

plt.scatter(X, y, color='red')

plt.plot(X_grid, regressor.predict(X_grid))

# %% [markdown]
# ## Learning in public
# 1. What is Random Forrest Regression
# 2. What is Ensemble Learning
